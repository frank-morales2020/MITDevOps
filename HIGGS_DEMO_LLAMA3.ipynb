# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MITDevOps/blob/master/HIGGS_DEMO_LLAMA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colab-env --quiet
import warnings

warnings.filterwarnings("ignore")

import colab_env
import os

access_token_write = os.getenv("HUGGINGFACE_ACCESS_TOKEN_WRITE")

from huggingface_hub import login

login(
  token=access_token_write,
  add_to_git_credential=True
)

# %%
import torch
import torch.nn as nn
from transformers import AutoModelForCausalLM, AutoTokenizer
import numpy as np
from scipy.stats import norm

# Check for GPU availability and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model_id = "meta-llama/Meta-Llama-3-8B"

try:
    # Load the pre-trained Llama 3 8B model and tokenizer on the selected device
    model = AutoModelForCausalLM.from_pretrained(model_id).to(device)
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    print(f"Successfully loaded {model_id}")
except Exception as e:
    print(f"Error loading {model_id}: {e}")
    print("Make sure you have access to this model and the necessary libraries are installed.")
    exit()

# --- Concrete (Standard) Hadamard Transform (1D) ---
def hadamard_transform_1d(x):
    n = x.shape[0]
    if n == 1:
        return x
    h_half = hadamard_transform_1d(x[:n//2])
    return torch.cat((h_half + x[n//2:], h_half - x[n//2:]), dim=0)

def apply_standard_hadamard(weight):
    original_shape = weight.shape
    flattened = weight.flatten()
    n = flattened.shape[0]
    if np.log2(n).is_integer():
        transformed = hadamard_transform_1d(flattened)
        return transformed.reshape(original_shape)
    else:
        # Pad to the nearest power of 2 (conceptual handling)
        next_power_of_2 = 2**int(np.ceil(np.log2(n)))
        padding = torch.zeros(next_power_of_2 - n, device=weight.device)  # Create padding on the same device
        padded = torch.cat((flattened, padding))
        transformed_padded = hadamard_transform_1d(padded)
        return transformed_padded[:n].reshape(original_shape)

# --- Gaussian-Inspired Quantization ---
def gaussian_inspired_quantize(tensor, num_bits):
    num_levels = 2**num_bits
    # Move tensor to CPU before calculating mean and std
    mean = tensor.float().cpu().mean()
    std = tensor.float().cpu().std()
    quantized = torch.zeros_like(tensor, dtype=torch.int, device=tensor.device) # Create quantized on the same device
    scale = (norm.ppf(0.99, loc=mean, scale=std) - norm.ppf(0.01, loc=mean, scale=std)) / (num_levels - 1) if num_levels > 1 else 1.0
    zero_point = -norm.ppf(0.01, loc=mean, scale=std) / scale if scale != 0 else 0

    normalized = (tensor - norm.ppf(0.01, loc=mean, scale=std)) / scale
    quantized = torch.round(torch.clamp(normalized, 0, num_levels - 1)).int()

    dequantized = (quantized.float() * scale) + norm.ppf(0.01, loc=mean, scale=std)
    return quantized, dequantized

import torch
import torch.nn as nn
from transformers import AutoModelForCausalLM, AutoTokenizer
import numpy as np
from scipy.stats import norm

def apply_conceptual_higgs_to_llama3(model, num_bits=4):
    for name, module in model.named_modules():
        if isinstance(module, nn.Linear) or isinstance(module, nn.Embedding):
            if hasattr(module, 'weight') and module.weight.requires_grad:
                # 1. Move original weights to CPU to free up GPU memory
                original_weights = module.weight.data.cpu().clone()

                # 2. Apply standard Hadamard transform
                transformed_weights = apply_standard_hadamard(original_weights)

                # 3. Apply Gaussian-inspired quantization
                quantized_weights, dequantized_weights = gaussian_inspired_quantize(transformed_weights, num_bits)

                # 4. Delete transformed_weights to free memory
                del transformed_weights

                # 5. Replace original weights and move back to GPU
                module.weight.data = dequantized_weights.to(device) # Move to GPU for inference/training
                print(f"Applied conceptual HIGGS (Hadamard + Gaussian quant) to {name}.weight")

                # 6. Delete unnecessary tensors
                del original_weights, quantized_weights, dequantized_weights

                # 7. Empty cache to free up memory
                torch.cuda.empty_cache()
# Out:
# Using device: cuda
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Successfully loaded meta-llama/Meta-Llama-3-8B

# %%
# Apply the conceptual HIGGS to the loaded Llama 3 model
apply_conceptual_higgs_to_llama3(model, num_bits=4)

print("\nModel weights after conceptual HIGGS:")
for name, param in model.named_parameters():
    print(name, param.dtype, param.shape, param.requires_grad)
# Out:
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.embed_tokens.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.0.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.1.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.2.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.3.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.4.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.5.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.6.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.7.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.8.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.9.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.10.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.11.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.12.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.13.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.14.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.15.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.16.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.17.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.18.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.19.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.20.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.21.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.22.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.23.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.24.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.25.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.26.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.27.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.28.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.29.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.30.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.self_attn.q_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.self_attn.k_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.self_attn.v_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.self_attn.o_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.mlp.gate_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.mlp.up_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to model.layers.31.mlp.down_proj.weight
# Applied conceptual HIGGS (Hadamard + Gaussian quant) to lm_head.weight
#
# Model weights after conceptual HIGGS:
# model.embed_tokens.weight torch.float32 torch.Size([128256, 4096]) True
# model.layers.0.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.0.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.0.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.0.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.0.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.0.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.0.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.0.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.0.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.1.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.1.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.1.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.1.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.1.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.1.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.1.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.1.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.1.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.2.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.2.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.2.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.2.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.2.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.2.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.2.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.2.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.2.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.3.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.3.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.3.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.3.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.3.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.3.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.3.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.3.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.3.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.4.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.4.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.4.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.4.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.4.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.4.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.4.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.4.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.4.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.5.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.5.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.5.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.5.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.5.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.5.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.5.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.5.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.5.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.6.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.6.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.6.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.6.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.6.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.6.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.6.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.6.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.6.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.7.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.7.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.7.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.7.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.7.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.7.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.7.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.7.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.7.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.8.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.8.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.8.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.8.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.8.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.8.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.8.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.8.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.8.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.9.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.9.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.9.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.9.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.9.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.9.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.9.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.9.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.9.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.10.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.10.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.10.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.10.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.10.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.10.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.10.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.10.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.10.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.11.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.11.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.11.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.11.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.11.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.11.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.11.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.11.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.11.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.12.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.12.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.12.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.12.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.12.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.12.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.12.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.12.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.12.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.13.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.13.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.13.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.13.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.13.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.13.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.13.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.13.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.13.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.14.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.14.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.14.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.14.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.14.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.14.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.14.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.14.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.14.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.15.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.15.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.15.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.15.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.15.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.15.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.15.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.15.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.15.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.16.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.16.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.16.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.16.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.16.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.16.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.16.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.16.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.16.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.17.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.17.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.17.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.17.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.17.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.17.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.17.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.17.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.17.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.18.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.18.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.18.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.18.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.18.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.18.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.18.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.18.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.18.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.19.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.19.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.19.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.19.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.19.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.19.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.19.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.19.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.19.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.20.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.20.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.20.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.20.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.20.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.20.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.20.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.20.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.20.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.21.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.21.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.21.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.21.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.21.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.21.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.21.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.21.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.21.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.22.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.22.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.22.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.22.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.22.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.22.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.22.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.22.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.22.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.23.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.23.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.23.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.23.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.23.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.23.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.23.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.23.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.23.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.24.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.24.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.24.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.24.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.24.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.24.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.24.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.24.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.24.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.25.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.25.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.25.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.25.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.25.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.25.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.25.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.25.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.25.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.26.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.26.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.26.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.26.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.26.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.26.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.26.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.26.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.26.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.27.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.27.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.27.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.27.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.27.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.27.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.27.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.27.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.27.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.28.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.28.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.28.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.28.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.28.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.28.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.28.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.28.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.28.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.29.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.29.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.29.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.29.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.29.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.29.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.29.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.29.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.29.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.30.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.30.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.30.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.30.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.30.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.30.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.30.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.30.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.30.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.31.self_attn.q_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.31.self_attn.k_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.31.self_attn.v_proj.weight torch.float32 torch.Size([1024, 4096]) True
# model.layers.31.self_attn.o_proj.weight torch.float32 torch.Size([4096, 4096]) True
# model.layers.31.mlp.gate_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.31.mlp.up_proj.weight torch.float32 torch.Size([14336, 4096]) True
# model.layers.31.mlp.down_proj.weight torch.float32 torch.Size([4096, 14336]) True
# model.layers.31.input_layernorm.weight torch.float32 torch.Size([4096]) True
# model.layers.31.post_attention_layernorm.weight torch.float32 torch.Size([4096]) True
# model.norm.weight torch.float32 torch.Size([4096]) True
# lm_head.weight torch.float32 torch.Size([128256, 4096]) True
